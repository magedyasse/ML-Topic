# %% [markdown]
# <a href="https://colab.research.google.com/github/magedyasse/ML-Topic/blob/Min-project-ml/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/uciml/iris")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: magedyaseer
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# ...
# 100%|██████████| 3.60k/3.60k [00:00<00:00, 4.72MB/s]

# %%
import pandas as pd

df = pd.read_csv("iris/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = df.drop(columns=['Id','Species'], axis=1)
y = df["Species"]

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
x.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 101            5.8           2.7            5.1           1.9
# 64             5.6           2.9            3.6           1.3
# 6              4.6           3.4            1.4           0.3
# 120            6.9           3.2            5.7           2.3
# 84             5.4           3.0            4.5           1.5

# %%
x.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
df_selected = df[features]
corr_matrix = df_selected.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Iris Features")
plt.show()

# %%
x.value_counts()
# Out:
# SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 4.9            3.1           1.5            0.1             3
# 5.8            2.7           5.1            1.9             2
# 4.3            3.0           1.1            0.1             1
# 4.4            3.2           1.3            0.2             1
# 4.5            2.3           1.3            0.3             1
#                                                            ..
# 7.7            2.6           6.9            2.3             1
#                2.8           6.7            2.0             1
#                3.0           6.1            2.3             1
#                3.8           6.7            2.2             1
# 7.9            3.8           6.4            2.0             1
# Name: count, Length: 147, dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
x.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].replace(["Iris-setosa","Iris-versicolor","Iris-virginica"], [1,0,2], inplace=True)
# Out:
# /tmp/ipython-input-23-3652515641.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species'].replace(["Iris-setosa","Iris-versicolor","Iris-virginica"], [1,0,2], inplace=True)

# %%
df[df.Species == 0].head(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 50  51            7.0           3.2            4.7           1.4        0
# 51  52            6.4           3.2            4.5           1.5        0
# 52  53            6.9           3.1            4.9           1.5        0
# 53  54            5.5           2.3            4.0           1.3        0
# 54  55            6.5           2.8            4.6           1.5        0

# %%
df[df.Species == 1].head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
df[df.Species == 2].head(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 100  101            6.3           3.3            6.0           2.5        2
# 101  102            5.8           2.7            5.1           1.9        2
# 102  103            7.1           3.0            5.9           2.1        2
# 103  104            6.3           2.9            5.6           1.8        2
# 104  105            6.5           3.0            5.8           2.2        2

# %%
df.Species.value_counts()
# Out:
# Species
# 1    50
# 0    50
# 2    50
# Name: count, dtype: int64

# %%
colors = {0: 'green', 1: 'blue', 2: 'red'}

for species, color in colors.items():
    subset = df[df['Species'] == species]
    plt.scatter(subset['SepalLengthCm'], subset['PetalLengthCm'],
                label=f"Species {species}", color=color)

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.title("Scatter Plot of Iris Dataset (Encoded Species)")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
print(x_train)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 22             4.6           3.6            1.0           0.2
# 15             5.7           4.4            1.5           0.4
# 65             6.7           3.1            4.4           1.4
# 11             4.8           3.4            1.6           0.2
# 42             4.4           3.2            1.3           0.2
# ..             ...           ...            ...           ...
# 71             6.1           2.8            4.0           1.3
# 106            4.9           2.5            4.5           1.7
# 14             5.8           4.0            1.2           0.2
# 92             5.8           2.6            4.0           1.2
# 102            7.1           3.0            5.9           2.1
#
# [120 rows x 4 columns]

# %%
print(y_train)
# Out:
# 22     1
# 15     1
# 65     0
# 11     1
# 42     1
#       ..
# 71     0
# 106    2
# 14     1
# 92     0
# 102    2
# Name: Species, Length: 120, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array([0, 1, 2, 0, 0])

# %%
y_test[:5].values
# Out:
# array([0, 1, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f} %")
# Out:
# Accuracy: 100.00 %

# %%
from sklearn.neighbors import KNeighborsClassifier


Knn = KNeighborsClassifier(n_neighbors=5)
Knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = Knn.predict(x_test)
y_pred[:5]
# Out:
# array([0, 1, 2, 0, 0])

# %%
y_test[:5].values
# Out:
# array([0, 1, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f} %")
# Out:
# Accuracy: 100.00 %
