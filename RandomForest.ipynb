# %% [markdown]
# <a href="https://colab.research.google.com/github/magedyasse/ML-Topic/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(
    'https://github.com/datagy/data/raw/main/titanic.csv',
    usecols=['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'])
data = data.dropna()

print(data.head())
# Out:
#    Survived  Pclass     Sex   Age  SibSp     Fare Embarked
# 0         0       3    male  22.0      1   7.2500        S
# 1         1       1  female  38.0      1  71.2833        C
# 2         1       3  female  26.0      0   7.9250        S
# 3         1       1  female  35.0      1  53.1000        S
# 4         0       3    male  35.0      0   8.0500        S

# %%
target = 'Survived'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Fare      712 non-null    float64
#  6   Embarked  712 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 44.5+ KB

# %%
data.describe(include='all').T
# Out:
#           count unique   top freq       mean        std   min   25%       50%  \
# Survived  712.0    NaN   NaN  NaN   0.404494   0.491139   0.0   0.0       0.0
# Pclass    712.0    NaN   NaN  NaN   2.240169   0.836854   1.0   1.0       2.0
# Sex         712      2  male  453        NaN        NaN   NaN   NaN       NaN
# Age       712.0    NaN   NaN  NaN  29.642093  14.492933  0.42  20.0      28.0
# SibSp     712.0    NaN   NaN  NaN   0.514045   0.930692   0.0   0.0       0.0
# Fare      712.0    NaN   NaN  NaN  34.567251  52.938648   0.0  8.05  15.64585
# Embarked    712      3     S  554        NaN        NaN   NaN   NaN       NaN
#
#            75%       max
# Survived   1.0       1.0
# Pclass     3.0       3.0
# Sex        NaN       NaN
# Age       38.0      80.0
# SibSp      1.0       5.0
# Fare      33.0  512.3292
# Embarked   NaN       NaN

# %%
data['Age'].fillna(data['Age'].median(), inplace=True)
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-411677293.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].median(), inplace=True)
# /tmp/ipython-input-411677293.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

# %%
data.describe(include='all').T
# Out:
#           count unique   top freq       mean        std   min   25%       50%  \
# Survived  712.0    NaN   NaN  NaN   0.404494   0.491139   0.0   0.0       0.0
# Pclass    712.0    NaN   NaN  NaN   2.240169   0.836854   1.0   1.0       2.0
# Sex         712      2  male  453        NaN        NaN   NaN   NaN       NaN
# Age       712.0    NaN   NaN  NaN  29.642093  14.492933  0.42  20.0      28.0
# SibSp     712.0    NaN   NaN  NaN   0.514045   0.930692   0.0   0.0       0.0
# Fare      712.0    NaN   NaN  NaN  34.567251  52.938648   0.0  8.05  15.64585
# Embarked    712      3     S  554        NaN        NaN   NaN   NaN       NaN
#
#            75%       max
# Survived   1.0       1.0
# Pclass     3.0       3.0
# Sex        NaN       NaN
# Age       38.0      80.0
# SibSp      1.0       5.0
# Fare      33.0  512.3292
# Embarked   NaN       NaN

# %%
data.describe().T
# Out:
#           count       mean        std   min    25%       50%   75%       max
# Survived  712.0   0.404494   0.491139  0.00   0.00   0.00000   1.0    1.0000
# Pclass    712.0   2.240169   0.836854  1.00   1.00   2.00000   3.0    3.0000
# Age       712.0  29.642093  14.492933  0.42  20.00  28.00000  38.0   80.0000
# SibSp     712.0   0.514045   0.930692  0.00   0.00   0.00000   1.0    5.0000
# Fare      712.0  34.567251  52.938648  0.00   8.05  15.64585  33.0  512.3292

# %%
sns.pairplot(data=data, hue='Survived')
plt.show()

# %%
X = data.copy()
y = X.pop('Survived')

# %%
X['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
X['Sex'].replace({'male': 0, 'female': 1}, inplace=True)
X['Embarked'].replace({'S': 0, 'C': 1, 'Q': 2}, inplace=True)
# Out:
# /tmp/ipython-input-3930076036.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Sex'].replace({'male': 0, 'female': 1}, inplace=True)
# /tmp/ipython-input-3930076036.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Sex'].replace({'male': 0, 'female': 1}, inplace=True)
# /tmp/ipython-input-3930076036.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Embarked'].replace({'S': 0, 'C': 1, 'Q': 2}, inplace=True)
# /tmp/ipython-input-3930076036.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Embarked'].replace({'S': 0, 'C': 1, 'Q': 2}, inplace=True)

# %%
sns.heatmap(X.corr(), annot=True ,linewidth=.5)
plt.show()

# %%
corr = X.corr()
corr
# Out:
#             Pclass       Sex       Age     SibSp      Fare  Embarked
# Pclass    1.000000 -0.150826 -0.365902  0.065187 -0.552893 -0.108502
# Sex      -0.150826  1.000000 -0.099037  0.106296  0.182457  0.097129
# Age      -0.365902 -0.099037  1.000000 -0.307351  0.093143  0.012186
# SibSp     0.065187  0.106296 -0.307351  1.000000  0.139860  0.004021
# Fare     -0.552893  0.182457  0.093143  0.139860  1.000000  0.176859
# Embarked -0.108502  0.097129  0.012186  0.004021  0.176859  1.000000

# %%
X.head()
# Out:
#    Pclass  Sex   Age  SibSp     Fare  Embarked
# 0       3    0  22.0      1   7.2500         0
# 1       1    1  38.0      1  71.2833         1
# 2       3    1  26.0      0   7.9250         0
# 3       1    1  35.0      1  53.1000         0
# 4       3    0  35.0      0   8.0500         0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (534, 6)
# (178, 6)
# (534,)
# (178,)

# %%
# pip install  optuna

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
import optuna

# %%
import optuna

def objective(trial):

    n_estimators = trial.suggest_int("n_estimators", 100, 500)
    max_depth = trial.suggest_int("max_depth", 2, 32)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 10)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
    max_features = trial.suggest_categorical("max_features", ["sqrt", "log2", None])

    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    # Use cross-validation to evaluate performance
    score = cross_val_score(clf, X_train, y_train, cv=3, scoring="accuracy")
    return score.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-31 17:55:30,789] A new study created in memory with name: no-name-3659a537-b497-44c1-8b7c-fa61e612fd76
# [I 2025-07-31 17:55:33,410] Trial 0 finished with value: 0.7921348314606741 and parameters: {'n_estimators': 347, 'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.7921348314606741.
# [I 2025-07-31 17:55:34,564] Trial 1 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 227, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.8127340823970037.
# [I 2025-07-31 17:55:36,938] Trial 2 finished with value: 0.8052434456928839 and parameters: {'n_estimators': 480, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 1 with value: 0.8127340823970037.
# [I 2025-07-31 17:55:40,121] Trial 3 finished with value: 0.7921348314606741 and parameters: {'n_estimators': 427, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 1 with value: 0.8127340823970037.
# [I 2025-07-31 17:55:41,265] Trial 4 finished with value: 0.8220973782771536 and parameters: {'n_estimators': 196, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:42,942] Trial 5 finished with value: 0.799625468164794 and parameters: {'n_estimators': 305, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:44,833] Trial 6 finished with value: 0.7921348314606741 and parameters: {'n_estimators': 357, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:45,947] Trial 7 finished with value: 0.8033707865168539 and parameters: {'n_estimators': 218, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:48,165] Trial 8 finished with value: 0.7902621722846442 and parameters: {'n_estimators': 444, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:49,304] Trial 9 finished with value: 0.8146067415730337 and parameters: {'n_estimators': 217, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:49,853] Trial 10 finished with value: 0.7808988764044944 and parameters: {'n_estimators': 114, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:51,305] Trial 11 finished with value: 0.8146067415730337 and parameters: {'n_estimators': 177, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:52,580] Trial 12 finished with value: 0.8052434456928839 and parameters: {'n_estimators': 141, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:54,025] Trial 13 finished with value: 0.799625468164794 and parameters: {'n_estimators': 246, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:55,415] Trial 14 finished with value: 0.8052434456928839 and parameters: {'n_estimators': 272, 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:56,302] Trial 15 finished with value: 0.7902621722846442 and parameters: {'n_estimators': 174, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:57,418] Trial 16 finished with value: 0.8146067415730337 and parameters: {'n_estimators': 187, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:59,162] Trial 17 finished with value: 0.8071161048689138 and parameters: {'n_estimators': 305, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:55:59,778] Trial 18 finished with value: 0.8089887640449437 and parameters: {'n_estimators': 112, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:01,119] Trial 19 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 260, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:02,964] Trial 20 finished with value: 0.8183520599250936 and parameters: {'n_estimators': 362, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:05,747] Trial 21 finished with value: 0.8183520599250936 and parameters: {'n_estimators': 355, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:07,536] Trial 22 finished with value: 0.8033707865168539 and parameters: {'n_estimators': 364, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:09,480] Trial 23 finished with value: 0.8089887640449439 and parameters: {'n_estimators': 393, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:11,353] Trial 24 finished with value: 0.7902621722846441 and parameters: {'n_estimators': 397, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:13,035] Trial 25 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 325, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:14,971] Trial 26 finished with value: 0.8108614232209739 and parameters: {'n_estimators': 393, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 4 with value: 0.8220973782771536.
# [I 2025-07-31 17:56:16,964] Trial 27 finished with value: 0.8239700374531836 and parameters: {'n_estimators': 280, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:18,989] Trial 28 finished with value: 0.7827715355805244 and parameters: {'n_estimators': 287, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:20,924] Trial 29 finished with value: 0.8071161048689138 and parameters: {'n_estimators': 332, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:21,722] Trial 30 finished with value: 0.801498127340824 and parameters: {'n_estimators': 151, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:23,548] Trial 31 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 365, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:25,383] Trial 32 finished with value: 0.799625468164794 and parameters: {'n_estimators': 341, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:27,680] Trial 33 finished with value: 0.8220973782771536 and parameters: {'n_estimators': 434, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:31,264] Trial 34 finished with value: 0.8071161048689138 and parameters: {'n_estimators': 489, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:33,466] Trial 35 finished with value: 0.8089887640449439 and parameters: {'n_estimators': 438, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:36,653] Trial 36 finished with value: 0.8202247191011236 and parameters: {'n_estimators': 461, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:39,264] Trial 37 finished with value: 0.7958801498127341 and parameters: {'n_estimators': 461, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:41,807] Trial 38 finished with value: 0.8108614232209738 and parameters: {'n_estimators': 468, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:45,482] Trial 39 finished with value: 0.8052434456928839 and parameters: {'n_estimators': 499, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:47,627] Trial 40 finished with value: 0.8146067415730337 and parameters: {'n_estimators': 422, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:49,877] Trial 41 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 448, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:51,999] Trial 42 finished with value: 0.8071161048689138 and parameters: {'n_estimators': 405, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:53,256] Trial 43 finished with value: 0.8089887640449437 and parameters: {'n_estimators': 234, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:55,916] Trial 44 finished with value: 0.8164794007490636 and parameters: {'n_estimators': 376, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:58,408] Trial 45 finished with value: 0.7865168539325843 and parameters: {'n_estimators': 423, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:56:59,423] Trial 46 finished with value: 0.799625468164794 and parameters: {'n_estimators': 204, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:57:01,932] Trial 47 finished with value: 0.797752808988764 and parameters: {'n_estimators': 471, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:57:03,503] Trial 48 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 306, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.
# [I 2025-07-31 17:57:04,942] Trial 49 finished with value: 0.8108614232209738 and parameters: {'n_estimators': 278, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 27 with value: 0.8239700374531836.

# %%
print("Best trial:")
print(study.best_trial)

print("\nBest parameters:")
print(study.best_params)
# Out:
# Best trial:
# FrozenTrial(number=27, state=1, values=[0.8239700374531836], datetime_start=datetime.datetime(2025, 7, 31, 17, 56, 14, 972738), datetime_complete=datetime.datetime(2025, 7, 31, 17, 56, 16, 964239), params={'n_estimators': 280, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_estimators': IntDistribution(high=500, log=False, low=100, step=1), 'max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'min_samples_split': IntDistribution(high=10, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=10, log=False, low=1, step=1), 'max_features': CategoricalDistribution(choices=('sqrt', 'log2', None))}, trial_id=27, value=None)
#
# Best parameters:
# {'n_estimators': 280, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}

# %%
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=1)

# %%
pred = model.predict(X_test)

# %%
print(pred[:5])
# Out:
# [1 1 0 0 0]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, pred))
print(accuracy_score(y_test, pred))
# Out:
# [[95  4]
#  [27 52]]
# 0.8258426966292135
